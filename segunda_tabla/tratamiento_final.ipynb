# %%
import pandas as pd #usamos la libreria de pandas para tratar los datos
from sqlalchemy import create_engine

# %%
df1=pd.read_csv('cine.csv')
df2=pd.read_csv('museo.csv')
df3=pd.read_csv('biblioteca_popular.csv')
engine= create_engine('postgresql://postgres:123456@localhost/proyecto_alkemy')

# %%
df2=df2.rename(columns={
       'categoria':'Categoría', 'subcategoria':'Subcategoria', 'provincia':'Provincia', 'localidad':'Localidad', 'nombre':'Nombre',
       'direccion':'Domicilio', 'piso':'Piso','telefono':'Teléfono','fuente':'Fuente'}) #cambiamos el nombre para tener todas las columnas equivalentes
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1182 entries, 0 to 1181
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Cod_Loc              1182 non-null   int64
#  1   IdProvincia          1182 non-null   int64
#  2   IdDepartamento       1182 non-null   int64
#  3   Observaciones        0 non-null      float64
#  4   Categoría            1182 non-null   object
#  5   Subcategoria         1048 non-null   object
#  6   Provincia            1182 non-null   object
#  7   Localidad            1182 non-null   object
#  8   Nombre               1182 non-null   object
#  9   Domicilio            1164 non-null   object
#  10  Piso                 0 non-null      float64
#  11  CP                   1116 non-null   object
#  12  cod_area             989 non-null    float64
#  13  Teléfono             988 non-null    object
#  14  Mail                 286 non-null    object
# ...

# %%
df1=df1.rename(columns={'Dirección':'Domicilio','año_actualizacion':'Año_actualizacion' }) #cambiamos el nombre para tener todas las columnas equivalentes
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 329 entries, 0 to 328
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Cod_Loc                329 non-null    int64
#  1   IdProvincia            329 non-null    int64
#  2   IdDepartamento         329 non-null    int64
#  3   Observaciones          0 non-null      float64
#  4   Categoría              329 non-null    object
#  5   Provincia              329 non-null    object
#  6   Departamento           329 non-null    object
#  7   Localidad              329 non-null    object
#  8   Nombre                 329 non-null    object
#  9   Domicilio              329 non-null    object
#  10  Piso                   329 non-null    object
#  11  CP                     329 non-null    int64
#  12  cod_area               329 non-null    object
#  13  Teléfono               329 non-null    object
# ...

# %%
df3[['Cod_Loc','Fuente']].head()
# Out:
#     Cod_Loc   Fuente
# 0  70049060  CONABIP
# 1   2000010  CONABIP
# 2   2000010  CONABIP
# 3   2000010  CONABIP
# 4   2000010  CONABIP

# %%
fusion = [df1,df2,df3]
archivo_final = pd.concat(fusion)
archivo_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3528 entries, 0 to 2016
# Data columns (total 35 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Cod_Loc                3528 non-null   int64
#  1   IdProvincia            3528 non-null   int64
#  2   IdDepartamento         3528 non-null   int64
#  3   Observaciones          0 non-null      float64
#  4   Categoría              3528 non-null   object
#  5   Provincia              3528 non-null   object
#  6   Departamento           2346 non-null   object
#  7   Localidad              3528 non-null   object
#  8   Nombre                 3528 non-null   object
#  9   Domicilio              3510 non-null   object
#  10  Piso                   329 non-null    object
#  11  CP                     3462 non-null   object
#  12  cod_area               1318 non-null   object
#  13  Teléfono               3334 non-null   object
# ...

# %%
#observo que tengo columnas nulos, por lo tanto las elimino
#archivo_final.drop(archivo_final.columns[[3,16,31]], axis=1, inplace=True)
archivo_final.info()
archivo_final.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3528 entries, 0 to 2016
# Data columns (total 35 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Cod_Loc                3528 non-null   int64
#  1   IdProvincia            3528 non-null   int64
#  2   IdDepartamento         3528 non-null   int64
#  3   Observaciones          0 non-null      float64
#  4   Categoría              3528 non-null   object
#  5   Provincia              3528 non-null   object
#  6   Departamento           2346 non-null   object
#  7   Localidad              3528 non-null   object
#  8   Nombre                 3528 non-null   object
#  9   Domicilio              3510 non-null   object
#  10  Piso                   329 non-null    object
#  11  CP                     3462 non-null   object
#  12  cod_area               1318 non-null   object
#  13  Teléfono               3334 non-null   object
# ...

# %%
archivo_final['Piso'] = archivo_final['Piso'].map({'s/d':np.nan})
archivo_final
# Out:
#        Cod_Loc  IdProvincia  IdDepartamento  Observaciones  \
# 0     10049030           10           10049            NaN
# 1     10091150           10           10091            NaN
# 2     22140060           22           22140            NaN
# 3     26091020           26           26091            NaN
# 4     18007010           18           18007            NaN
# ...        ...          ...             ...            ...
# 2012  62042560           62           62042            NaN
# 2013  70028010           70           70028            NaN
# 2014  62007080           62           62007            NaN
# 2015  62077010           62           62077            NaN
# 2016  62042360           62           62042            NaN
#
#                   Categoría   Provincia   Departamento  \
# 0             Salas de cine   Catamarca        Capital
# 1             Salas de cine   Catamarca    Santa Maria
# 2             Salas de cine       Chaco   San Fernando
# ...

# %%
#CANTIDAD DE REGISTROS TOTALES POR FUENTE

cantidad_fuente=archivo_final.groupby(['Fuente']) #con la funcion 'groupby' por podemos obtener los totales de cada columna por las categorias existentes
cantidad_fuente=cantidad_fuente.size() #obtengo la cantidad total por fuente

cantidad_fuente=pd.DataFrame(cantidad_fuente, columns=['total'])
cantidad_fuente=cantidad_fuente.reset_index()
cantidad_fuente.to_sql('cantidad_por_fuente', engine, index=False, if_exists='append')

# %%
#CANTIDAD DE REGISTROS TOTALES POR CATEGORIA

cantidad_categoria=archivo_final.groupby(['Categoría']) #con la funcion 'groupby' por podemos obtener los totales de cada columna por las categorias existentes
cantidad_categoria=cantidad_categoria.size() #obtengo la cantidad total por fuente

cantidad_categoria=pd.DataFrame(cantidad_categoria, columns=['total']) # con esta funcion me encargo de tranformar la serie en dataframe
cantidad_categoria=cantidad_categoria.reset_index() #Con esta opcion me encargo de tranformar el indice como columna
cantidad_categoria.to_sql('cantidad_por_categoria', engine, index=False, if_exists='append')

# %%
provincia_categoria=archivo_final.groupby(['Provincia', 'Categoría']) # los agrupo primero por provincia, luego por categoria
provincia_categoria=provincia_categoria.size()
cantidad
provincia_categoria=provincia_categoria.reset_index()
provincia_categoria.to_sql('cantidad_por_categoriaypronvincia', engine, index=False, if_exists='append')

# %%
fusion = [cantidad_fuente,cantidad_categoria,provincia_categoria]
final = pd.concat(fusion)
final.head(50)
#final[['Provincia','Categoría','Fuente','total']]
# Out:
#                                                Fuente  total  \
# 0                                CNMLH - Enlace SInCA      1
# 1                    CNMLH - Ente Cultural de Tucumán      1
# 2                                             CONABIP   2010
# 3                                               DNPyM   1048
# 4   Dirección Provincial de Patrimonio Cultural - ...      1
# 5               Dirección de Cultura de Villa Allende      2
# 6   Dirección de Cultura y de Educación de la Muni...      1
# 7                                          Gob. Pcia.      1
# 8                            Gobierno de la Provincia     14
# 9     Gobierno de la Provincia de Chubut / SInCA 2013      3
# 10                  Gobierno de la Provincia de Jujuy      4
# 11               Gobierno de la Provincia de La Pampa      1
# 12               Gobierno de la Provincia de La Rioja      1
# 13                Gobierno de la Provincia de Mendoza      4
# ...
